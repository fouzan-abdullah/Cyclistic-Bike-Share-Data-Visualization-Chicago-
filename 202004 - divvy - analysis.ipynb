# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Preparing the data

# %%
df04 = pd.read_csv(r'H:\Fouzan\Coursera\Google Data Project\Zipped\Extracted Files\CSV Files\202004-divvy-tripdata.csv')
df05 = pd.read_csv(r'H:\Fouzan\Coursera\Google Data Project\Zipped\Extracted Files\CSV Files\202005-divvy-tripdata.csv')

# %%
df07 = pd.read_csv(r'H:\Fouzan\Coursera\Google Data Project\Zipped\Extracted Files\CSV Files\202007-divvy-tripdata.csv')
df07['started_at'] = pd.to_datetime(df07['started_at'], dayfirst = True)
df07['ended_at'] = pd.to_datetime(df07['ended_at'], dayfirst = True)

# %%
df08 = pd.read_csv(r'H:\Fouzan\Coursera\Google Data Project\Zipped\Extracted Files\CSV Files\202008-divvy-tripdata.csv')
df08['started_at'] = pd.to_datetime(df08['started_at'], dayfirst = True)
df08['ended_at'] = pd.to_datetime(df08['ended_at'], dayfirst = True)

# %%
df09 = pd.read_csv(r'H:\Fouzan\Coursera\Google Data Project\Zipped\Extracted Files\CSV Files\202009-divvy-tripdata.csv')
df09['started_at'] = pd.to_datetime(df09['started_at'], dayfirst = True)
df09['ended_at'] = pd.to_datetime(df09['ended_at'], dayfirst = True)

# %%
df10 = pd.read_csv(r'H:\Fouzan\Coursera\Google Data Project\Zipped\Extracted Files\CSV Files\202010-divvy-tripdata.csv')
df10['started_at'] = pd.to_datetime(df10['started_at'], dayfirst = True)
df10['ended_at'] = pd.to_datetime(df10['ended_at'], dayfirst = True)

# %%
df11 = pd.read_csv(r'H:\Fouzan\Coursera\Google Data Project\Zipped\Extracted Files\CSV Files\202011-divvy-tripdata.csv')
df11['started_at'] = pd.to_datetime(df11['started_at'], dayfirst = True)
df11['ended_at'] = pd.to_datetime(df11['ended_at'], dayfirst = True)

# %%
df12 = pd.read_csv(r'H:\Fouzan\Coursera\Google Data Project\Zipped\Extracted Files\CSV Files\202012-divvy-tripdata.csv')
df12['started_at'] = pd.to_datetime(df12['started_at'], dayfirst = True)
df12['ended_at'] = pd.to_datetime(df12['ended_at'], dayfirst = True)

# %%
df06 = pd.read_csv(r'H:\Fouzan\Coursera\Google Data Project\Zipped\Extracted Files\CSV Files\202006-divvy-tripdata.csv')
df06['started_at'] = pd.to_datetime(df06['started_at'], dayfirst = True)
df06['ended_at'] = pd.to_datetime(df06['ended_at'], dayfirst = True)

# %%
df04 = pd.read_csv(r'H:\Fouzan\Coursera\Google Data Project\Zipped\Extracted Files\CSV Files\202004-divvy-tripdata.csv')
df04['started_at'] = pd.to_datetime(df04['started_at'], dayfirst = True)
df04['ended_at'] = pd.to_datetime(df04['ended_at'], dayfirst = True)

df05 = pd.read_csv(r'H:\Fouzan\Coursera\Google Data Project\Zipped\Extracted Files\CSV Files\202005-divvy-tripdata.csv')
df05['started_at'] = pd.to_datetime(df05['started_at'], dayfirst = True)
df05['ended_at'] = pd.to_datetime(df05['ended_at'], dayfirst = True)

# %%
dfm = pd.concat([df04, df05, df06, df07, df08, df09, df10, df11, df12])
dfm
# Out:
#                  ride_id  rideable_type          started_at  \
# 0       A847FADBBC638E45    docked_bike 2020-04-26 17:45:14
# 1       5405B80E996FF60D    docked_bike 2020-04-17 17:08:54
# 2       5DD24A79A4E006F4    docked_bike 2020-04-01 17:54:13
# 3       2A59BBDF5CDBA725    docked_bike 2020-04-07 12:50:19
# 4       27AD306C119C6158    docked_bike 2020-04-18 10:22:59
# ...                  ...            ...                 ...
# 131568  4631EE956BCEA738   classic_bike 2020-12-19 13:59:00
# 131569  D17CBEDEA8DBDFF6  electric_bike 2020-12-20 15:48:00
# 131570  447A6C67E9AF962E    docked_bike 2020-12-02 16:59:00
# 131571  F558C17E95751C62  electric_bike 2020-12-20 18:06:00
# 131572  E1888F4B274EEA12  electric_bike 2020-12-03 09:43:00
#
#                   ended_at            start_station_name start_station_id  \
# 0      2020-04-26 18:12:03                  Eckhart Park               86
# 1      2020-04-17 17:17:03     Drake Ave & Fullerton Ave              503
# ...

# %%
dfm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3114796 entries, 0 to 131572
# Data columns (total 13 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       object
#  2   started_at          datetime64[ns]
#  3   ended_at            datetime64[ns]
#  4   start_station_name  object
#  5   start_station_id    object
#  6   end_station_name    object
#  7   end_station_id      object
#  8   start_lat           float64
#  9   start_lng           float64
#  10  end_lat             float64
#  11  end_lng             float64
#  12  member_casual       object
# dtypes: datetime64[ns](2), float64(4), object(7)
# memory usage: 332.7+ MB

# %%
dfm['Month'] = dfm['started_at'].dt.month
dfm['Month'].unique()
# Out:
# array([ 4,  5,  6,  7,  8,  9, 10, 11, 12], dtype=int64)

# %%
dfm.to_csv('year2020.csv')

# %% [markdown]
# Now we will prepare the dataframe according to our requirements

# %% [markdown]
# We will do the following changes:
# 1. Make a duration column.
# 2. Extract month as a numeric value.
# 3. Extract day of week as numeric value.

# %%
dfm['week'] = dfm['started_at'].dt.dayofweek
dfm['duration'] = (dfm['ended_at'] - dfm['started_at'])
dfm
# Out:
#                  ride_id  rideable_type          started_at  \
# 0       A847FADBBC638E45    docked_bike 2020-04-26 17:45:14
# 1       5405B80E996FF60D    docked_bike 2020-04-17 17:08:54
# 2       5DD24A79A4E006F4    docked_bike 2020-04-01 17:54:13
# 3       2A59BBDF5CDBA725    docked_bike 2020-04-07 12:50:19
# 4       27AD306C119C6158    docked_bike 2020-04-18 10:22:59
# ...                  ...            ...                 ...
# 131568  4631EE956BCEA738   classic_bike 2020-12-19 13:59:00
# 131569  D17CBEDEA8DBDFF6  electric_bike 2020-12-20 15:48:00
# 131570  447A6C67E9AF962E    docked_bike 2020-12-02 16:59:00
# 131571  F558C17E95751C62  electric_bike 2020-12-20 18:06:00
# 131572  E1888F4B274EEA12  electric_bike 2020-12-03 09:43:00
#
#                   ended_at            start_station_name start_station_id  \
# 0      2020-04-26 18:12:03                  Eckhart Park               86
# 1      2020-04-17 17:17:03     Drake Ave & Fullerton Ave              503
# ...

# %%
dfm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3114796 entries, 0 to 131572
# Data columns (total 16 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       object
#  2   started_at          datetime64[ns]
#  3   ended_at            datetime64[ns]
#  4   start_station_name  object
#  5   start_station_id    object
#  6   end_station_name    object
#  7   end_station_id      object
#  8   start_lat           float64
#  9   start_lng           float64
#  10  end_lat             float64
#  11  end_lng             float64
#  12  member_casual       object
#  13  Month               int64
#  14  week                int64
#  15  duration            timedelta64[ns]
# dtypes: datetime64[ns](2), float64(4), int64(2), object(7), timedelta64[ns](1)
# memory usage: 404.0+ MB

# %%
#saving original df
df = dfm

# %% [markdown]
# dropping the columns ride_id, started_at, ended_at

# %%
df = df.drop(['ride_id','started_at','ended_at'],axis = 1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3114796 entries, 0 to 131572
# Data columns (total 13 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   rideable_type       object
#  1   start_station_name  object
#  2   start_station_id    object
#  3   end_station_name    object
#  4   end_station_id      object
#  5   start_lat           float64
#  6   start_lng           float64
#  7   end_lat             float64
#  8   end_lng             float64
#  9   member_casual       object
#  10  Month               int64
#  11  week                int64
#  12  duration            timedelta64[ns]
# dtypes: float64(4), int64(2), object(6), timedelta64[ns](1)
# memory usage: 332.7+ MB

# %%
df.shape
# Out:
# (3114796, 13)

# %% [markdown]
# making seperate dfs for annual members and casual members

# %%
dfmm = df.loc[(df['member_casual'] == 'member')]
dfmm
# Out:
#         rideable_type                   start_station_name start_station_id  \
# 0         docked_bike                         Eckhart Park               86
# 1         docked_bike            Drake Ave & Fullerton Ave              503
# 2         docked_bike                 McClurg Ct & Erie St              142
# 3         docked_bike         California Ave & Division St              216
# 5         docked_bike  Mies van der Rohe Way & Chicago Ave              173
# ...               ...                                  ...              ...
# 131567   classic_bike                 Rhodes Ave & 32nd St            13215
# 131569  electric_bike                 Rhodes Ave & 32nd St            13215
# 131570    docked_bike                 Rhodes Ave & 32nd St            13215
# 131571  electric_bike                 Rhodes Ave & 32nd St            13215
# 131572  electric_bike                 Rhodes Ave & 32nd St            13215
#
# ...

# %%
dfc = df.loc[(df['member_casual'] == 'casual')]
dfc
# Out:
#         rideable_type           start_station_name start_station_id  \
# 4         docked_bike         Rush St & Hubbard St              125
# 7         docked_bike     Ogden Ave & Roosevelt Rd              434
# 8         docked_bike        LaSalle Dr & Huron St              627
# 17        docked_bike      Leavitt St & Archer Ave                9
# 18        docked_bike       Clark St & Lincoln Ave              141
# ...               ...                          ...              ...
# 131561   classic_bike         Rhodes Ave & 32nd St            13215
# 131562  electric_bike    Bissell St & Armitage Ave            13059
# 131563   classic_bike  Sheffield Ave & Webster Ave     TA1309000033
# 131564  electric_bike  Sheffield Ave & Webster Ave     TA1309000033
# 131568   classic_bike         Rhodes Ave & 32nd St            13215
#
#                       end_station_name end_station_id  start_lat  start_lng  \
# ...

# %% [markdown]
# we will do EDA on dfmm and then try to predict for dfc

# %%
dfmm.isnull().sum()
# Out:
# rideable_type             0
# start_station_name    56418
# start_station_id      56690
# end_station_name      61743
# end_station_id        61954
# start_lat                 0
# start_lng                 0
# end_lat                2257
# end_lng                2257
# member_casual             0
# Month                     0
# week                      0
# duration                  0
# dtype: int64

# %% [markdown]
# the columns for which all rows have null values, we will delete those

# %%
dfmm.to_csv('dfmm.csv')
dfc.to_csv('dfc.csv')

# %%
dfmm
# Out:
#         rideable_type                   start_station_name start_station_id  \
# 0         docked_bike                         Eckhart Park               86
# 1         docked_bike            Drake Ave & Fullerton Ave              503
# 2         docked_bike                 McClurg Ct & Erie St              142
# 3         docked_bike         California Ave & Division St              216
# 5         docked_bike  Mies van der Rohe Way & Chicago Ave              173
# ...               ...                                  ...              ...
# 131567   classic_bike                 Rhodes Ave & 32nd St            13215
# 131569  electric_bike                 Rhodes Ave & 32nd St            13215
# 131570    docked_bike                 Rhodes Ave & 32nd St            13215
# 131571  electric_bike                 Rhodes Ave & 32nd St            13215
# 131572  electric_bike                 Rhodes Ave & 32nd St            13215
#
# ...

# %% [markdown]
# filling wrong values with right ones

# %%
dfmm.loc[(dfmm['end_station_id'] == 'TA1308000036')]
# Out:
#         rideable_type    start_station_name start_station_id  \
# 6273    electric_bike    State St & 35th St     TA1307000129
# 6274     classic_bike    State St & 35th St     TA1307000129
# 6275    electric_bike    State St & 35th St     TA1307000129
# 6276    electric_bike    State St & 35th St     TA1307000129
# 6290     classic_bike    State St & 35th St     TA1307000129
# ...               ...                   ...              ...
# 131567   classic_bike  Rhodes Ave & 32nd St            13215
# 131569  electric_bike  Rhodes Ave & 32nd St            13215
# 131570    docked_bike  Rhodes Ave & 32nd St            13215
# 131571  electric_bike  Rhodes Ave & 32nd St            13215
# 131572  electric_bike  Rhodes Ave & 32nd St            13215
#
#              end_station_name end_station_id  start_lat  start_lng    end_lat  \
# 6273    Indiana Ave & 31st St   TA1308000036  41.831072 -87.627051  41.838764
# ...

# %%
dfmm.loc[(dfmm['end_station_name'] == 'Indiana Ave & 31st St')]
# Out:
#         rideable_type     start_station_name start_station_id  \
# 3091      docked_bike  Indiana Ave & 31st St              272
# 3092      docked_bike  Indiana Ave & 31st St              272
# 3381      docked_bike  Indiana Ave & 31st St              272
# 3431      docked_bike     State St & 29th St              193
# 3553      docked_bike  Indiana Ave & 31st St              272
# ...               ...                    ...              ...
# 131567   classic_bike   Rhodes Ave & 32nd St            13215
# 131569  electric_bike   Rhodes Ave & 32nd St            13215
# 131570    docked_bike   Rhodes Ave & 32nd St            13215
# 131571  electric_bike   Rhodes Ave & 32nd St            13215
# 131572  electric_bike   Rhodes Ave & 32nd St            13215
#
#              end_station_name end_station_id  start_lat  start_lng    end_lat  \
# 3091    Indiana Ave & 31st St            272  41.838800 -87.621900  41.838800
# ...

# %%
#replacing cell value

#dfmm.loc[(dfmm['start_station_id'] == 'TA1308000036'), 'start_station_id'] = 272
#dfmm.loc[(dfmm['end_station_id'] == 'TA1308000036'), 'end_station_id'] = 272
# Out:
# C:\Users\fouza\anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
df10['start_station_name'].nunique()
# Out:
# 669

# %%
#dfmm.loc[(dfmm['start_station_id'].str)]
# Out:
#          Unnamed: 0  rideable_type                   start_station_name  \
# 0                 0    docked_bike                         Eckhart Park
# 1                 1    docked_bike            Drake Ave & Fullerton Ave
# 2                 2    docked_bike                 McClurg Ct & Erie St
# 3                 3    docked_bike         California Ave & Division St
# 4                 5    docked_bike  Mies van der Rohe Way & Chicago Ave
# ...             ...            ...                                  ...
# 1796696      131567   classic_bike                 Rhodes Ave & 32nd St
# 1796697      131569  electric_bike                 Rhodes Ave & 32nd St
# 1796698      131570    docked_bike                 Rhodes Ave & 32nd St
# 1796699      131571  electric_bike                 Rhodes Ave & 32nd St
# 1796700      131572  electric_bike                 Rhodes Ave & 32nd St
#
#         start_station_id             end_station_name end_station_id  \
# ...

# %%
#dfmm[dfmm['end_station_id'].apply(len) > 3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-91-4cb2e196cfe8> in <module>
# ----> 1 dfmm[dfmm['end_station_id'].apply(len) > 3]
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4198             else:
#    4199                 values = self.astype(object)._values
# -> 4200                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4201
#    4202         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# TypeError: object of type 'float' has no len()

# %%
dfmm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1796701 entries, 0 to 1796700
# Data columns (total 14 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Unnamed: 0          int64
#  1   rideable_type       object
#  2   start_station_name  object
#  3   start_station_id    object
#  4   end_station_name    object
#  5   end_station_id      object
#  6   start_lat           float64
#  7   start_lng           float64
#  8   end_lat             float64
#  9   end_lng             float64
#  10  member_casual       object
#  11  Month               int64
#  12  week                int64
#  13  duration            object
# dtypes: float64(4), int64(3), object(7)
# memory usage: 191.9+ MB

# %%
#dfmm['start_station_id'].apply(str)
# Out:
# 0             86
# 1            503
# 2            142
# 3            216
# 4            173
#            ...
# 1796696    13215
# 1796697    13215
# 1796698    13215
# 1796699    13215
# 1796700    13215
# Name: start_station_id, Length: 1796701, dtype: object

# %%
#dfmm[dfmm['start_station_id'].apply(len) > 3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-101-68fc4e717089> in <module>
# ----> 1 dfmm[dfmm['start_station_id'].apply(len) > 3]
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4198             else:
#    4199                 values = self.astype(object)._values
# -> 4200                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4201
#    4202         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# TypeError: object of type 'int' has no len()
