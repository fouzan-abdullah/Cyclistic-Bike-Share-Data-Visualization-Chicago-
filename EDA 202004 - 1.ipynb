# %% [markdown]
# ## A more detailed analysis of the Divvy Chicago Bike Share data.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #### Loading the data.

# %%
df = pd.read_csv('202004-divvy-tripdata.csv')
df
# Out:
#                 ride_id rideable_type           started_at  \
# 0      A847FADBBC638E45   docked_bike  2020-04-26 17:45:14
# 1      5405B80E996FF60D   docked_bike  2020-04-17 17:08:54
# 2      5DD24A79A4E006F4   docked_bike  2020-04-01 17:54:13
# 3      2A59BBDF5CDBA725   docked_bike  2020-04-07 12:50:19
# 4      27AD306C119C6158   docked_bike  2020-04-18 10:22:59
# ...                 ...           ...                  ...
# 84771  200E9CDFC5685AA0   docked_bike  2020-04-16 16:10:16
# 84772  F58A8F2ABCB5D95B   docked_bike  2020-04-30 17:56:12
# 84773  A3754693A80E4913   docked_bike  2020-04-24 19:57:33
# 84774  D610CABB67F7B744   docked_bike  2020-04-02 17:59:55
# 84775  79634521ABE4CF69   docked_bike  2020-04-04 01:31:27
#
#                   ended_at            start_station_name  start_station_id  \
# 0      2020-04-26 18:12:03                  Eckhart Park                86
# 1      2020-04-17 17:17:03     Drake Ave & Fullerton Ave               503
# 2      2020-04-01 18:08:36          McClurg Ct & Erie St               142
# 3      2020-04-07 13:02:31  California Ave & Division St               216
# 4      2020-04-18 11:15:54          Rush St & Hubbard St               125
# ...                    ...                           ...               ...
# 84771  2020-04-16 16:23:11   Dearborn Pkwy & Delaware Pl               140
# 84772  2020-04-30 18:15:21         Kimbark Ave & 53rd St               322
# 84773  2020-04-24 21:50:43     Sedgwick St & Schiller St               236
# 84774  2020-04-02 18:42:26     Damen Ave & Charleston St               310
# 84775  2020-04-04 01:37:27    Clybourn Ave & Division St               138
#
#                   end_station_name  end_station_id  start_lat  start_lng  \
# 0      Lincoln Ave & Diversey Pkwy           152.0    41.8964   -87.6610
# 1                  Kosciuszko Park           499.0    41.9244   -87.7154
# 2       Indiana Ave & Roosevelt Rd           255.0    41.8945   -87.6179
# 3           Wood St & Augusta Blvd           657.0    41.9030   -87.6975
# 4       Sheridan Rd & Lawrence Ave           323.0    41.8902   -87.6262
# ...                            ...             ...        ...        ...
# 84771  Dearborn Pkwy & Delaware Pl           140.0    41.8990   -87.6299
# 84772  Cottage Grove Ave & 51st St           351.0    41.7996   -87.5947
# 84773            Wells St & Elm St           182.0    41.9076   -87.6386
# 84774    Damen Ave & Charleston St           310.0    41.9201   -87.6779
# 84775   Clybourn Ave & Division St           138.0    41.9046   -87.6406
#
#        end_lat  end_lng member_casual
# 0      41.9322 -87.6586        member
# 1      41.9306 -87.7238        member
# 2      41.8679 -87.6230        member
# 3      41.8992 -87.6722        member
# 4      41.9695 -87.6547        casual
# ...        ...      ...           ...
# 84771  41.8990 -87.6299        member
# 84772  41.8030 -87.6066        casual
# 84773  41.9032 -87.6343        casual
# 84774  41.9201 -87.6779        casual
# 84775  41.9046 -87.6406        casual
#
# [84776 rows x 13 columns]

# %% [markdown]
# we currently won't work with the geographical points, and station names are also not needed. We will only analyze with numeric information for the time being.

# %% [markdown]
# #### Cleaning and Sorting

# %%
#deleting unnecessary columns
df = df.drop(['rideable_type','ride_id','start_lat','start_lng','end_lat','end_lng','start_station_name','end_station_name'], axis = 1)
df
# Out:
#                 started_at             ended_at  start_station_id  \
# 0      2020-04-26 17:45:14  2020-04-26 18:12:03                86
# 1      2020-04-17 17:08:54  2020-04-17 17:17:03               503
# 2      2020-04-01 17:54:13  2020-04-01 18:08:36               142
# 3      2020-04-07 12:50:19  2020-04-07 13:02:31               216
# 4      2020-04-18 10:22:59  2020-04-18 11:15:54               125
# ...                    ...                  ...               ...
# 84771  2020-04-16 16:10:16  2020-04-16 16:23:11               140
# 84772  2020-04-30 17:56:12  2020-04-30 18:15:21               322
# 84773  2020-04-24 19:57:33  2020-04-24 21:50:43               236
# 84774  2020-04-02 17:59:55  2020-04-02 18:42:26               310
# 84775  2020-04-04 01:31:27  2020-04-04 01:37:27               138
#
#        end_station_id member_casual
# 0               152.0        member
# 1               499.0        member
# 2               255.0        member
# 3               657.0        member
# 4               323.0        casual
# ...               ...           ...
# 84771           140.0        member
# 84772           351.0        casual
# 84773           182.0        casual
# 84774           310.0        casual
# 84775           138.0        casual
#
# [84776 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84776 entries, 0 to 84775
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   started_at        84776 non-null  object
#  1   ended_at          84776 non-null  object
#  2   start_station_id  84776 non-null  int64
#  3   end_station_id    84677 non-null  float64
#  4   member_casual     84776 non-null  object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 3.2+ MB

# %%
#we want to find ride duration so need to change to datetime format
df['started_at'] = df['started_at'].astype('datetime64')
df['ended_at'] = df['ended_at'].astype('datetime64')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84776 entries, 0 to 84775
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   started_at        84776 non-null  datetime64[ns]
#  1   ended_at          84776 non-null  datetime64[ns]
#  2   start_station_id  84776 non-null  int64
#  3   end_station_id    84677 non-null  float64
#  4   member_casual     84776 non-null  object
# dtypes: datetime64[ns](2), float64(1), int64(1), object(1)
# memory usage: 3.2+ MB

# %%
df['duration'] = (df['ended_at'] - df['started_at'])
df.head(2)
# Out:
#            started_at            ended_at  start_station_id  end_station_id  \
# 0 2020-04-26 17:45:14 2020-04-26 18:12:03                86           152.0
# 1 2020-04-17 17:08:54 2020-04-17 17:17:03               503           499.0
#
#   member_casual        duration
# 0        member 0 days 00:26:49
# 1        member 0 days 00:08:09

# %%
#converting duration to seconds for easier manipulation
df['duration'] = df['duration'] / np.timedelta64(1, 's')
df.head(4)
# Out:
#            started_at            ended_at  start_station_id  end_station_id  \
# 0 2020-04-26 17:45:14 2020-04-26 18:12:03                86           152.0
# 1 2020-04-17 17:08:54 2020-04-17 17:17:03               503           499.0
# 2 2020-04-01 17:54:13 2020-04-01 18:08:36               142           255.0
# 3 2020-04-07 12:50:19 2020-04-07 13:02:31               216           657.0
#
#   member_casual  duration
# 0        member    1609.0
# 1        member     489.0
# 2        member     863.0
# 3        member     732.0

# %%
df['weekday'] = df['started_at'].dt.dayofweek
df
# Out:
#                started_at            ended_at  start_station_id  \
# 0     2020-04-26 17:45:14 2020-04-26 18:12:03                86
# 1     2020-04-17 17:08:54 2020-04-17 17:17:03               503
# 2     2020-04-01 17:54:13 2020-04-01 18:08:36               142
# 3     2020-04-07 12:50:19 2020-04-07 13:02:31               216
# 4     2020-04-18 10:22:59 2020-04-18 11:15:54               125
# ...                   ...                 ...               ...
# 84771 2020-04-16 16:10:16 2020-04-16 16:23:11               140
# 84772 2020-04-30 17:56:12 2020-04-30 18:15:21               322
# 84773 2020-04-24 19:57:33 2020-04-24 21:50:43               236
# 84774 2020-04-02 17:59:55 2020-04-02 18:42:26               310
# 84775 2020-04-04 01:31:27 2020-04-04 01:37:27               138
#
#        end_station_id member_casual  duration  weekday
# 0               152.0        member    1609.0        6
# 1               499.0        member     489.0        4
# 2               255.0        member     863.0        2
# 3               657.0        member     732.0        1
# 4               323.0        casual    3175.0        5
# ...               ...           ...       ...      ...
# 84771           140.0        member     775.0        3
# 84772           351.0        casual    1149.0        3
# 84773           182.0        casual    6790.0        4
# 84774           310.0        casual    2551.0        3
# 84775           138.0        casual     360.0        5
#
# [84776 rows x 7 columns]

# %%
#now for extracting month
df['Month'] = df['started_at'].dt.month
df
# Out:
#                started_at            ended_at  start_station_id  \
# 0     2020-04-26 17:45:14 2020-04-26 18:12:03                86
# 1     2020-04-17 17:08:54 2020-04-17 17:17:03               503
# 2     2020-04-01 17:54:13 2020-04-01 18:08:36               142
# 3     2020-04-07 12:50:19 2020-04-07 13:02:31               216
# 4     2020-04-18 10:22:59 2020-04-18 11:15:54               125
# ...                   ...                 ...               ...
# 84771 2020-04-16 16:10:16 2020-04-16 16:23:11               140
# 84772 2020-04-30 17:56:12 2020-04-30 18:15:21               322
# 84773 2020-04-24 19:57:33 2020-04-24 21:50:43               236
# 84774 2020-04-02 17:59:55 2020-04-02 18:42:26               310
# 84775 2020-04-04 01:31:27 2020-04-04 01:37:27               138
#
#        end_station_id member_casual  duration  weekday  Month
# 0               152.0        member    1609.0        6      4
# 1               499.0        member     489.0        4      4
# 2               255.0        member     863.0        2      4
# 3               657.0        member     732.0        1      4
# 4               323.0        casual    3175.0        5      4
# ...               ...           ...       ...      ...    ...
# 84771           140.0        member     775.0        3      4
# 84772           351.0        casual    1149.0        3      4
# 84773           182.0        casual    6790.0        4      4
# 84774           310.0        casual    2551.0        3      4
# 84775           138.0        casual     360.0        5      4
#
# [84776 rows x 8 columns]

# %% [markdown]
# Now that we have all the useful information in our desired format we will delete the started at and ended at columns.

# %%
df = df.drop(['started_at','ended_at'],axis = 1)
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84776 entries, 0 to 84775
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   start_station_id  84776 non-null  int64
#  1   end_station_id    84677 non-null  float64
#  2   member_casual     84776 non-null  object
#  3   duration          84776 non-null  float64
#  4   weekday           84776 non-null  int64
#  5   Month             84776 non-null  int64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 3.9+ MB
#        start_station_id  end_station_id member_casual  duration  weekday  \
# 0                    86           152.0        member    1609.0        6
# 1                   503           499.0        member     489.0        4
# 2                   142           255.0        member     863.0        2
# 3                   216           657.0        member     732.0        1
# 4                   125           323.0        casual    3175.0        5
# ...                 ...             ...           ...       ...      ...
# 84771               140           140.0        member     775.0        3
# 84772               322           351.0        casual    1149.0        3
# 84773               236           182.0        casual    6790.0        4
# 84774               310           310.0        casual    2551.0        3
# 84775               138           138.0        casual     360.0        5
#
#        Month
# 0          4
# 1          4
# 2          4
# 3          4
# 4          4
# ...      ...
# 84771      4
# 84772      4
# 84773      4
# 84774      4
# 84775      4
#
# [84776 rows x 6 columns]

# %% [markdown]
# #### Saving for later use.

# %%
w0420 = df

# %%
w0420.to_csv('w0420.csv')

# %% [markdown]
# checking null values

# %%
df.isnull().sum()
# Out:
# start_station_id     0
# end_station_id      99
# member_casual        0
# duration             0
# weekday              0
# Month                0
# dtype: int64

# %%
df1 = df[df.isna().any(axis=1)]
df1
# Out:
#        start_station_id  end_station_id member_casual  duration  weekday  \
# 1001                289             NaN        member    2127.0        1
# 1864                343             NaN        member     298.0        0
# 2167                 15             NaN        member   10312.0        3
# 2458                137             NaN        casual    3669.0        3
# 3834                157             NaN        member    1552.0        5
# ...                 ...             ...           ...       ...      ...
# 83383                21             NaN        casual   34774.0        2
# 83881               535             NaN        member    1877.0        0
# 84306               232             NaN        member    1876.0        3
# 84415               539             NaN        member      15.0        0
# 84551               123             NaN        casual     937.0        3
#
#        Month
# 1001       4
# 1864       4
# 2167       4
# 2458       4
# 3834       4
# ...      ...
# 83383      4
# 83881      4
# 84306      4
# 84415      4
# 84551      4
#
# [99 rows x 6 columns]

# %%
df1.loc[(df1['start_station_id'] == 535)]
# Out:
#        start_station_id  end_station_id member_casual  duration  weekday  \
# 83881               535             NaN        member    1877.0        0
#
#        Month
# 83881      4

# %% [markdown]
# Lets leave the NA values out of the analysis.

# %% [markdown]
# Filtering out the annual members.

# %%
df1 = df.loc[(df['member_casual'] == 'member')]
df1
# Out:
#        start_station_id  end_station_id member_casual  duration  weekday  \
# 0                    86           152.0        member    1609.0        6
# 1                   503           499.0        member     489.0        4
# 2                   142           255.0        member     863.0        2
# 3                   216           657.0        member     732.0        1
# 5                   173            35.0        member     324.0        3
# ...                 ...             ...           ...       ...      ...
# 84767               126           106.0        member     482.0        6
# 84768               268           141.0        member    2129.0        6
# 84769               268           268.0        member       8.0        6
# 84770               106           268.0        member     425.0        6
# 84771               140           140.0        member     775.0        3
#
#        Month
# 0          4
# 1          4
# 2          4
# 3          4
# 5          4
# ...      ...
# 84767      4
# 84768      4
# 84769      4
# 84770      4
# 84771      4
#
# [61148 rows x 6 columns]

# %% [markdown]
# #### Starting the analysis.

# %%
df1.groupby(['weekday']).sum().sort_values('duration', ascending = False)
# Out:
#          start_station_id  end_station_id    duration  Month
# weekday
# 6                 2763800       2750126.0  18349524.0  45760
# 5                 2071231       2089704.0  13752484.0  35368
# 1                 2142010       2128850.0  11931316.0  36628
# 3                 2148687       2126061.0  11114134.0  37056
# 0                 1871893       1881569.0   8615312.0  32256
# 4                 1731916       1729498.0   8227987.0  29848
# 2                 1592413       1589254.0   6770926.0  27676

# %% [markdown]
# The duration column in above table tells us that Sunday was the busiest day for cycling trips and Wednesday was the least busy. Note: Disregard the other columns they don't mean anything in this table.

# %%
df1.groupby(['weekday']).count().sort_values('duration', ascending = False)
# Out:
#          start_station_id  end_station_id  member_casual  duration  Month
# weekday
# 6                   11440           11429          11440     11440  11440
# 3                    9264            9256           9264      9264   9264
# 1                    9157            9146           9157      9157   9157
# 5                    8842            8833           8842      8842   8842
# 0                    8064            8055           8064      8064   8064
# 4                    7462            7454           7462      7462   7462
# 2                    6919            6916           6919      6919   6919

# %% [markdown]
# The duration column in this table tells us the number of bike trips made on every day. We can see that after Sunday, the most bike trips were made on Thursday, followed by Tuesday and then Saturday.
#
# So we know now that people tend to take longer rides on weekends. Note also that in both the tables, sorted by trip duration and number of rides respectively, the top 4 spots are taken by the same days i.e. Sunday, Saturday, Tuesday and Thursday.
#
# Interesting...no?
#
# Note: Again, the other columns mean nothing in this instance so ignore them.

# %% [markdown]
# Now we want to know the sum of duration for each station from where bike was rented.

# %%
#pivot table showing sum of trip duration per start_station_id and in the columns we have every day of the week starting from Monday.
p3 = pd.pivot_table(df1, values='duration', index='start_station_id', columns='weekday', aggfunc='sum', fill_value=None, margins=False, dropna=True, margins_name='All', observed=False) 
p3
# Out:
# weekday                 0        1        2        3        4         5  \
# start_station_id
# 2                 29473.0  30674.0  12063.0  16854.0  19330.0  106368.0
# 3                   931.0    504.0      NaN   2361.0      NaN     929.0
# 4                     NaN      NaN      NaN      NaN    694.0       NaN
# 5                 11652.0  14910.0   9072.0   8850.0  10840.0    6512.0
# 6                     NaN   3028.0      NaN   1217.0   1635.0       NaN
# ...                   ...      ...      ...      ...      ...       ...
# 663                5059.0  10206.0   6950.0   6870.0   2494.0    5309.0
# 664                3595.0   3311.0   5623.0   6346.0   5626.0       NaN
# 666                   NaN   1232.0    372.0   1103.0   3901.0    8963.0
# 672               23086.0  25409.0  16188.0  28893.0  48298.0   32312.0
# 673               23508.0  39933.0  12251.0  23157.0  15058.0   40699.0
#
# weekday                  6
# start_station_id
# 2                 104923.0
# 3                   4828.0
# 4                      NaN
# 5                  12563.0
# 6                      NaN
# ...                    ...
# 663                 8265.0
# 664                 1164.0
# 666                 9795.0
# 672                30698.0
# 673                52126.0
#
# [586 rows x 7 columns]

# %%
p1 = pd.pivot_table(df1, values='duration', index='start_station_id', columns=None , aggfunc='sum')

# %%
#sorting from longest duration
long_dur = p1.sort_values(ascending = False, by = 'duration')
long_dur
# Out:
#                    duration
# start_station_id
# 194               3643342.0
# 642               3252788.0
# 17                2322205.0
# 138                753011.0
# 282                672609.0
# ...                     ...
# 583                   783.0
# 4                     694.0
# 445                   632.0
# 588                   532.0
# 536                   210.0
#
# [586 rows x 1 columns]

# %% [markdown]
# This table tells us that station id 194 holds the esteemed position of being the station of choice from where the cumulatively longest rides were booked. Would be good to single out the top ten or so stations in this for further analysis.
#
# Now lets arrange this table via count. And then check again.

# %%
p2 = pd.pivot_table(df1, values='duration', index='start_station_id', columns=None , aggfunc='count') 
most_rides = p2.sort_values(ascending = False, by = 'duration')
most_rides
# Out:
#                   duration
# start_station_id
# 176                    604
# 211                    593
# 110                    545
# 56                     516
# 94                     451
# ...                    ...
# 588                      1
# 651                      1
# 562                      1
# 649                      1
# 431                      1
#
# [586 rows x 1 columns]

# %% [markdown]
# Here the numbers tell a different story. Maybe the stations from where the longest duration rides were issued were on the outskirts of the city or far away from the business districts, while the number of rides from these stations tells us that they were near, or in the business districts itself. All of this is conjecture, yet.

# %% [markdown]
# Lets compare these numbers via days also. Maybe it will give a new angle to these observations.

# %%
#p3 is the pivot table we called earlier. Aggregating by sum of duration and sorting by station name and weekdays.
p3.sort_values(ascending = False, by = 6)
# Out:
# weekday                 0         1        2        3        4        5  \
# start_station_id
# 194               14401.0   14975.0  18665.0  18707.0   9143.0  25024.0
# 118               27099.0   35997.0  18850.0  23390.0  18135.0  41220.0
# 324               46911.0   66067.0  30143.0  48138.0  37292.0  75982.0
# 330                4171.0   10969.0    591.0   9565.0   3913.0   5535.0
# 316               20128.0    9462.0   8008.0   7921.0   1598.0  15523.0
# ...                   ...       ...      ...      ...      ...      ...
# 590                   NaN       NaN      NaN      NaN      NaN   3859.0
# 593                7564.0       NaN      NaN      NaN   2091.0   1446.0
# 639                2085.0       NaN      NaN      NaN      NaN      NaN
# 650                 836.0       NaN      NaN   2308.0      NaN   1118.0
# 651                   NaN  522227.0      NaN      NaN      NaN      NaN
#
# weekday                   6
# start_station_id
# 194               3542427.0
# 118                248749.0
# 324                200694.0
# 330                196377.0
# 316                190803.0
# ...                     ...
# 590                     NaN
# 593                     NaN
# 639                     NaN
# 650                     NaN
# 651                     NaN
#
# [586 rows x 7 columns]

# %% [markdown]
# Turns out we can only sort via individual day. No problem, we know sunday was the busiest day. So we sorted by Sunday and as we can see the station id on top looks familiar, doesn't it? Yes its the same station from which the longest rides were started.
#
# Changing the weekday in the code will tell us which station issued the cumulatively longest rides on that day.

# %% [markdown]
# Lets play some more with the pivot table.

# %%
p4 = pd.pivot_table(df1, values='duration', index=['start_station_id'], columns='end_station_id', aggfunc='sum', fill_value=None, margins=False, dropna=True, margins_name='All', observed=False)
p4
# Out:
# end_station_id      2.0    3.0     5.0    6.0     7.0    9.0    11.0   12.0   \
# start_station_id
# 2                 18594.0    NaN  1573.0    NaN  3878.0    NaN    NaN    NaN
# 3                   504.0    NaN     NaN    NaN     NaN    NaN    NaN    NaN
# 4                     NaN    NaN     NaN    NaN     NaN    NaN    NaN    NaN
# 5                     NaN    NaN  8221.0    NaN     NaN    NaN    NaN    NaN
# 6                     NaN    NaN     NaN  235.0  1554.0    NaN    NaN    NaN
# ...                   ...    ...     ...    ...     ...    ...    ...    ...
# 663                   NaN    NaN     NaN    NaN     NaN    NaN    NaN    NaN
# 664                   NaN    NaN     NaN    NaN     NaN    NaN    NaN    NaN
# 666                   NaN    NaN     NaN    NaN     NaN    NaN    NaN    NaN
# 672                   NaN    NaN     NaN    NaN     NaN    NaN    NaN    NaN
# 673                   NaN    NaN     NaN    NaN     NaN    NaN    NaN    NaN
#
# end_station_id     13.0   14.0   ...   659.0  660.0  661.0  662.0    663.0  \
# start_station_id                 ...
# 2                    NaN    NaN  ...  2048.0    NaN    NaN    NaN      NaN
# 3                    NaN    NaN  ...     NaN    NaN    NaN    NaN      NaN
# 4                    NaN    NaN  ...     NaN    NaN    NaN    NaN      NaN
# 5                    NaN    NaN  ...     NaN    NaN    NaN    NaN      NaN
# 6                    NaN    NaN  ...     NaN    NaN    NaN    NaN      NaN
# ...                  ...    ...  ...     ...    ...    ...    ...      ...
# 663                  NaN    NaN  ...     NaN    NaN    NaN    NaN  32845.0
# 664                  NaN    NaN  ...     NaN    NaN    NaN    NaN      NaN
# 666               1795.0    NaN  ...  2878.0    NaN    NaN    NaN      NaN
# 672                  NaN    NaN  ...     NaN    NaN    NaN    NaN      NaN
# 673                  NaN    NaN  ...     NaN    NaN    NaN    NaN      NaN
#
# end_station_id     664.0  666.0  671.0    672.0    673.0
# start_station_id
# 2                    NaN    NaN    NaN      NaN      NaN
# 3                    NaN    NaN    NaN      NaN      NaN
# 4                    NaN    NaN    NaN      NaN      NaN
# 5                    NaN    NaN    NaN      NaN      NaN
# 6                    NaN    NaN    NaN      NaN      NaN
# ...                  ...    ...    ...      ...      ...
# 663                  NaN    NaN    NaN      NaN      NaN
# 664               2694.0    NaN    NaN      NaN      NaN
# 666                  NaN    NaN    NaN      NaN      NaN
# 672                  NaN    NaN    NaN  30794.0    876.0
# 673                  NaN    NaN    NaN      NaN  42481.0
#
# [586 rows x 582 columns]

# %%
df194 = p4.iloc[175:176]
df194[df194.columns[~df194.isnull().all()]]
# Out:
# end_station_id     7.0     17.0   18.0    24.0    25.0    26.0    28.0   \
# start_station_id
# 194               1101.0  1625.0  316.0  4793.0  2332.0  4259.0  2167.0
#
# end_station_id     31.0    33.0   35.0   ...   301.0   321.0   329.0  394.0  \
# start_station_id                         ...
# 194               1286.0  2064.0  961.0  ...  4167.0  1540.0  3503.0  661.0
#
# end_station_id     442.0   623.0  627.0      671.0  672.0   673.0
# start_station_id
# 194               2948.0  2033.0  395.0  3523202.0  692.0  3617.0
#
# [1 rows x 59 columns]

# %%
df194 = df194.transpose()
df194
# Out:
# start_station_id        194
# end_station_id
# 2.0                     NaN
# 3.0                     NaN
# 5.0                     NaN
# 6.0                     NaN
# 7.0                  1101.0
# ...                     ...
# 664.0                   NaN
# 666.0                   NaN
# 671.0             3523202.0
# 672.0                 692.0
# 673.0                3617.0
#
# [582 rows x 1 columns]

# %%
df194 = df194.dropna()
df194.sort_values(ascending = False, by = 194)
# Out:
# start_station_id        194
# end_station_id
# 671.0             3523202.0
# 194.0                7939.0
# 176.0                6862.0
# 220.0                5992.0
# 144.0                5338.0
# 24.0                 4793.0
# 255.0                4578.0
# 199.0                4420.0
# 26.0                 4259.0
# 301.0                4167.0
# 673.0                3617.0
# 56.0                 3535.0
# 329.0                3503.0
# 299.0                3162.0
# 442.0                2948.0
# 39.0                 2636.0
# 25.0                 2332.0
# 28.0                 2167.0
# 69.0                 2075.0
# 33.0                 2064.0
# 256.0                2052.0
# 623.0                2033.0
# 272.0                1984.0
# 38.0                 1888.0
# 110.0                1836.0
# 81.0                 1793.0
# 61.0                 1746.0
# 59.0                 1740.0
# 142.0                1637.0
# 17.0                 1625.0
# 157.0                1576.0
# 44.0                 1542.0
# 321.0                1540.0
# 127.0                1357.0
# 112.0                1355.0
# 31.0                 1286.0
# 54.0                 1162.0
# 94.0                 1131.0
# 109.0                1109.0
# 7.0                  1101.0
# 300.0                1099.0
# 35.0                  961.0
# 84.0                  872.0
# 289.0                 784.0
# 48.0                  778.0
# 195.0                 723.0
# 50.0                  711.0
# 672.0                 692.0
# 89.0                  687.0
# 71.0                  678.0
# 394.0                 661.0
# 197.0                 643.0
# 100.0                 623.0
# 106.0                 510.0
# 91.0                  431.0
# 627.0                 395.0
# 211.0                 371.0
# 161.0                 325.0
# 18.0                  316.0

# %% [markdown]
# This tells us that the most rides or the longest duration rides from station 194 ended their journey at station 671. If we do this for the ten busiest stations according to count and according to cumulative trip duration we can find some interesting patterns.

# %% [markdown]
# So now we will seperate out the five busiest stations in the long_dur and most_rides tables, and then find out their most sought after destination station, like we just did above for station id 194.

# %% [markdown]
# ##### Platform Nine and three quarters?

# %%
long_dur
# Out:
#                    duration
# start_station_id
# 194               3643342.0
# 642               3252788.0
# 17                2322205.0
# 138                753011.0
# 282                672609.0
# ...                     ...
# 583                   783.0
# 4                     694.0
# 445                   632.0
# 588                   532.0
# 536                   210.0
#
# [586 rows x 1 columns]

# %% [markdown]
# So we will find for station id 642, 17, 138 and 282.

# %%
df17 = p4.iloc[13:14]
df17 = df17.transpose()
df17 = df17.dropna()
df17 = df17.sort_values(ascending = False, by = 17)
df17
# Out:
# start_station_id         17
# end_station_id
# 658.0             2169922.0
# 17.0                18342.0
# 236.0                6663.0
# 622.0                6649.0
# 128.0                6290.0
# ...                     ...
# 16.0                  407.0
# 374.0                 401.0
# 29.0                  293.0
# 30.0                  256.0
# 69.0                  221.0
#
# [67 rows x 1 columns]

# %% [markdown]
# Most visited station from station id 17 = station id 658

# %% [markdown]
# Now for station id 138.

# %%
df138 = p4.iloc[124:125]
df138 = df138.transpose()
df138 = df138.dropna()
df138 = df138.sort_values(ascending = False, by = 138)
df138
# Out:
# start_station_id       138
# end_station_id
# 211.0             631560.0
# 133.0               6378.0
# 115.0               5565.0
# 635.0               5517.0
# 289.0               5211.0
# ...                    ...
# 27.0                 597.0
# 94.0                 441.0
# 53.0                 388.0
# 140.0                377.0
# 48.0                 224.0
#
# [62 rows x 1 columns]

# %% [markdown]
# Most visited station from station id 138 = station id 211.

# %%
df283 = p4.iloc[259:260]
df283 = df283.transpose()
df283 = df283.dropna()
df283 = df283.sort_values(ascending = False, by = 283)
df283
# Out:
# start_station_id      283
# end_station_id
# 42.0              11752.0
# 492.0             10376.0
# 74.0               9853.0
# 211.0              7567.0
# 23.0               4443.0
# 156.0              4208.0
# 289.0              4143.0
# 292.0              3285.0
# 627.0              2960.0
# 283.0              2636.0
# 59.0               2553.0
# 229.0              2472.0
# 49.0               2455.0
# 199.0              2419.0
# 338.0              2151.0
# 223.0              2142.0
# 110.0              2094.0
# 158.0              1895.0
# 140.0              1817.0
# 174.0              1736.0
# 301.0              1703.0
# 91.0               1625.0
# 442.0              1476.0
# 340.0              1460.0
# 193.0              1425.0
# 659.0              1382.0
# 27.0               1338.0
# 175.0              1211.0
# 81.0               1197.0
# 66.0                945.0
# 282.0               907.0
# 134.0               883.0
# 7.0                 804.0
# 25.0                698.0
# 53.0                693.0
# 173.0               668.0
# 26.0                625.0
# 2.0                 576.0
# 106.0               555.0
# 195.0               481.0
# 321.0               396.0
# 44.0                340.0
# 77.0                307.0
# 90.0                279.0
# 192.0               271.0
# 38.0                264.0
# 169.0               264.0
# 98.0                263.0
# 73.0                260.0
# 39.0                136.0
# 50.0                133.0

# %% [markdown]
# Hmm..this information doesn't tell much. There is no special destination logging way more than the other stations in duration. So we will not go forward with this station's destination.

# %% [markdown]
# Now the same exercise for stations with most_rides.

# %%
most_rides
# Out:
#                   duration
# start_station_id
# 176                    604
# 211                    593
# 110                    545
# 56                     516
# 94                     451
# ...                    ...
# 588                      1
# 651                      1
# 562                      1
# 649                      1
# 431                      1
#
# [586 rows x 1 columns]

# %% [markdown]
# Finding hot destinations for station id's 176,211,110,56 and 94.

# %%
temp = p4.iloc[259:260]
def hot(stid):
    global temp
    temp = temp.transpose()
    temp = temp.dropna()
    temp = temp.sort_values(ascending = False, by = stid)
    return temp
df283 = hot(283)
df283.head()
# Out:
# start_station_id      283
# end_station_id
# 42.0              11752.0
# 492.0             10376.0
# 74.0               9853.0
# 211.0              7567.0
# 23.0               4443.0

# %%
temp = p4.iloc[159:160]
df176 = hot(176)
df176.head()
# Out:
# start_station_id      176
# end_station_id
# 176.0             73812.0
# 364.0             20395.0
# 199.0             16235.0
# 77.0              15044.0
# 180.0             14466.0

# %% [markdown]
# Most visited station from station id 176 = station id 176.

# %%
temp = p4.iloc[192:193]
df211 = hot(211)
df211.head()
# Out:
# start_station_id      211
# end_station_id
# 211.0             47118.0
# 91.0              32599.0
# 255.0             22971.0
# 127.0             17875.0
# 289.0             16471.0

# %% [markdown]
# Not significant.

# %%
temp = p4.iloc[96:97]
df110 = hot(110)
df110.head()
# Out:
# start_station_id       110
# end_station_id
# 110.0             109182.0
# 199.0              21364.0
# 117.0              19607.0
# 59.0               17184.0
# 166.0              15576.0

# %% [markdown]
# Most visited station from station id 110 = station id 110.

# %%
temp = p4.iloc[52:53]
df56 = hot(56)
df56.head()
# Out:
# start_station_id       56
# end_station_id
# 56.0              53773.0
# 84.0              17726.0
# 210.0             16086.0
# 173.0             12197.0
# 657.0             10948.0

# %% [markdown]
# Most visited station from station id 56 = station id 56.

# %%
temp = p4.iloc[82:83]
df94 = hot(94)
df94.head()
# Out:
# start_station_id       94
# end_station_id
# 94.0              46839.0
# 176.0             26067.0
# 156.0             18112.0
# 211.0              9428.0
# 288.0              8822.0

# %% [markdown]
# Most visited station from station id 94 = station id 94.

# %% [markdown]
# For the stations with most rides, the most popular destination stations were the same as the starting stations.
